# %%
# Test basique
print("Bonjour IOAI !")

import numpy as np
print("NumPy version :", np.__version__)

import torch
print("PyTorch version :", torch.__version__)
# Out:
# Bonjour IOAI !
# NumPy version : 1.26.4
# PyTorch version : 2.5.1+cu121

# %%
#include <iostream>

int main() {
    std::cout << "Bonjour IOAI !" << std::endl;
    return 0;
}
